# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### q1
#
# SELECT * FROM your_table_name
# WHERE skills IN ('Tableau', 'SQL', 'Python');

# %% [markdown]
# ### q2
#
# select pr_id from product_info pi join product_info_likes pl on pi.pr_id=pl.pr_id where pl.liked_date is null
